# %%
import numpy as np

import matplotlib.pyplot as plt

import ai_prentice_wasserstein
import utils

# %%
coupled_oscillator_data = np.load("trajectories/coupled_oscillator.npz")
data = coupled_oscillator_data["data"]

# %%
ai_prentice = ai_prentice_wasserstein.DimensionalityPrentice()

# %%
ai_prentice.fit(data)
# Out:
# Normalizing
# Computing distance matrix
# Embedding data and computing scores
# Computing the dimensionality

# %%
embedding = ai_prentice.embeddings[2]
energies = coupled_oscillator_data["params"]

# %%
plt.rcParams.update({'font.size': 18})

# %%
utils.plot_scores(plt.gca(), ai_prentice.scores, ai_prentice.errors)
# plt.savefig("graphs/co_scores.pdf")
plt.show()

# %%
utils.plot_score_diffs(plt.gca(), ai_prentice.scores, ai_prentice.errors, ai_prentice.dimensionality, ai_prentice.threshold)
# plt.savefig("graphs/co_diffs.pdf")
plt.show()

# %%
utils.plot_2d(*plt.subplots(figsize=(7, 5)), embedding, energies[:, 0], "E1")
# plt.savefig("graphs/co_energy1.pdf")
plt.show()

utils.plot_2d(*plt.subplots(figsize=(7, 5)), embedding, energies[:, 1], "E2")
# plt.savefig("graphs/co_energy2.pdf")
plt.show()

# %%
plt.subplot()

for traj in data[:3]:
    plt.scatter(*traj[:, [0, 2]].T)
plt.xlabel("position 1")
plt.ylabel("momentum 1")

# plt.savefig("graphs/co_data1.pdf")

plt.show()

plt.subplot()

for traj in data[:3]:
    plt.scatter(*traj[:, [1, 3]].T)
plt.xlabel("position 2")
plt.ylabel("momentum 2")

# plt.savefig("graphs/co_data2.pdf")
plt.show()
