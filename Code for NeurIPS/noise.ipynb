# %%
import utils
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 14})

# %%
prentices_ho = utils.prentices_with_noise(np.load("trajectories/harmonic_oscillator.npz")["data"])
# Out:
# 100%|██████████| 40/40 [1:42:37<00:00, 153.95s/it]

# %%
utils.plot_dimensionalities(plt.gca(), prentices_ho, 1)
plt.savefig("graphs/ho_noise.pdf")
plt.show()

# %%
prentices_pend = utils.prentices_with_noise(np.load("trajectories/pendulum.npz")["data"])
# Out:
# 100%|██████████| 40/40 [1:41:39<00:00, 152.50s/it]

# %%
utils.plot_dimensionalities(plt.gca(), prentices_pend, 1)
plt.savefig("graphs/pend_noise.pdf")
plt.show()

# %%
prentices_co = utils.prentices_with_noise(np.load("trajectories/coupled_oscillator.npz")["data"])
# Out:
# 100%|██████████| 40/40 [1:50:29<00:00, 165.73s/it]

# %%
utils.plot_dimensionalities(plt.gca(), prentices_co, 2)
plt.savefig("graphs/co_noise.pdf")
plt.show()

# %%
prentices_kp = utils.prentices_with_noise(np.load("trajectories/kepler_problem.npz")["data"])
# Out:
# 100%|██████████| 40/40 [2:40:17<00:00, 240.44s/it]

# %%
utils.plot_dimensionalities(plt.gca(), prentices_kp, 3)
plt.savefig("graphs/kp_noise.pdf")
plt.show()

# %%
prentices_dp = utils.prentices_with_noise(np.load("trajectories/double_pendulum.npz")["data"])
# Out:
#   5%|▌         | 2/40 [09:58<3:09:25, 299.10s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-7720448b9bf4> in <module>
# ----> 1 prentices_dp = utils.prentices_with_noise(np.load("trajectories/double_pendulum.npz")["data"])
#
# ~/manifold project/ai-prentice-conservation-laws/utils/noise.py in prentices_with_noise(data, strength_arr)
#      13     for strength in tqdm(strength_arr):
#      14         ai_prentice = ai_prentice_wasserstein.DimensionalityPrentice(verbosity=0)
# ---> 15         ai_prentice.fit(data + np.random.normal(scale=scale * strength, size=(data.shape)))
#      16         prentices.append(ai_prentice)
#      17     return prentices
#
# ~/manifold project/ai-prentice-conservation-laws/ai_prentice_wasserstein.py in fit(self, data, ws_distance_matrix)
#      47             if self.verbosity:
#      48                 print("Computing distance matrix")
# ---> 49             ws_distance_matrix = gen_dist_matrix(data, beta=self.beta)
#      50         self.ws_distance_matrix = ws_distance_matrix
#      51
#
# ~/manifold project/ai-prentice-conservation-laws/utils/dist_matrix.py in gen_dist_matrix(X, use_sinkhorn, beta, name)
#      17     weighted_data = np.array([np.array([np.array([1] + list(b)) for b in a]) for a in X])
#      18     pw_emd = ws.PairwiseEMD(beta=beta)
# ---> 19     pw_emd(weighted_data)
#      20     dist_matrix = pw_emd.emds()
#      21     dist_matrix[dist_matrix < 0] = 0
#
# ~/.local/lib/python3.8/site-packages/wasserstein/wasserstein.py in __call__(self, eventsA, eventsB, gdim, mask, event_weightsA, event_weightsB)
#     474
#     475         if not self.request_mode():
# --> 476             self.compute()
#     477
#     478     emds = _swig_new_instance_method(_wasserstein.PairwiseEMDBaseFloat64_emds)
#
# RuntimeError: KeyboardInterrupt received in PairwiseEMD::compute

# %%
utils.plot_dimensionalities(plt.gca(), prentices_dp, 1)
plt.show()
plt.savefig("graphs/dp_noise.pdf")

# %%
prentices_turing = utils.prentices_with_noise(np.load("trajectories/turing.npz")["data"])

# %%
utils.plot_dimensionalities(plt.gca(), prentices_turing, 1)
plt.show()
plt.savefig("graphs/turing_noise.pdf")
