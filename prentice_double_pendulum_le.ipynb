# %%
import numpy as np

import matplotlib.pyplot as plt

import ai_prentice_wasserstein
import utils

# %%
double_pendulum_le_data = np.load("trajectories/double_pendulum_low_energy.npz")
data = double_pendulum_le_data["data"]

# %%
ai_prentice = ai_prentice_wasserstein.DimensionalityPrentice()

# %%
ai_prentice.fit(data)
# Out:
# Normalizing
# Computing distance matrix
# Embedding data and computing scores
# Computing the dimensionality

# %%
embedding = ai_prentice.embeddings[2]
energies = double_pendulum_le_data["params"]

# %%
plt.rcParams.update({'font.size': 18})

# %%
utils.plot_scores(plt.gca(), ai_prentice.scores, ai_prentice.errors)
# plt.savefig("graphs/dp_le_scores.pdf")
plt.show()

# %%
utils.plot_score_diffs(plt.gca(), ai_prentice.scores, ai_prentice.errors, ai_prentice.dimensionality, ai_prentice.threshold)
# plt.savefig("graphs/dp_le_diffs.pdf")
plt.show()

# %%
for i in [0, 1]:
    utils.plot_2d(*plt.subplots(figsize=(7, 5)), embedding, energies[:, i], f"E{i + 1}")
    # plt.savefig(f"graphs/dp_le_energy{i + 1}.pdf")
    plt.show()
